# %% [markdown]
# # My First Notebook

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
x='python' #define a variable x

# %%
print(x)
# Out:
# python

# %%
x
# Out:
# 'python'

# %%
print(x + ' review')
# Out:
# python review

# %%
print(x + 4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(x + 4)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print('Testing: {one}, {two}'.format(one=x, two=4))
# Out:
# Testing: python, 4

# %%
print('{}, {}'.format(x, 4))
# Out:
# python, 4

# %%
[1, 2, 3]
# Out:
# [1, 2, 3]

# %%
['hello', 2, [3, 4]]
# Out:
# ['hello', 2, [3, 4]]

# %%
myList = [1, 2, 3]
myList.append('d')
print(myList)
# Out:
# [1, 2, 3, 'd']

# %%
myList[2]
# Out:
# 3

# %%
myList[2:]
# Out:
# [3, 'd']

# %%
myList[:2]
# Out:
# [1, 2]

# %%
myList[0] ='a'

# %%
print(myList)
# Out:
# ['a', 2, 3, 'd']

# %% [markdown]
# <h2>Dictionaries</h2>

# %%
di={'key1':'value1', 'key2':5}
di['key1']
# Out:
# 'value1'

# %% [markdown]
# <h2>Sets</h2>

# %%
{1, 2, 3}
# Out:
# {1, 2, 3}

# %%
{1, 2, 3, 3, 3, 2, 1, 3, 3, 1, 1}
# Out:
# {1, 2, 3}

# %% [markdown]
# <h2>Comparison Operators</h2>

# %%
1>2
# Out:
# False

# %%
1<2
# Out:
# True

# %%
(1<2) and (1>2)
# Out:
# False

# %%
(1<2) or (1>2)
# Out:
# True

# %%
if 1>2:
    print('a')
elif 1==2:
    print('b')
elif 2==2:
    print('c')
else:
    print('d')

# %%
i = 1
while i <= 5:
    print('i is: {}'.format(i))

# %% [markdown]
# # Functions

# %%
def my_function(param1, param2='default'):
    print('param1 is: {}'.format(param1))
    print('param2 is: {}'.format(param2))

# %%
my_function(4)
# Out:
# param1 is: 4
# param2 is: default

# %%
my_function(4, 5)
# Out:
# param1 is: 4
# param2 is: 5

# %%
def prog_tax(salary=0):
    if salary <=40000:
        return '${:.2f}'.format(salary*0.20)
    elif salary <=100000:
        return '${:.2f}'.format(8000+((salary-40000)*0.30))
    elif salary >100000:
        return '${:.2f}'.format(26000+((salary-100000)*0.40))
    else:
        return "could not calculate"

# %%
prog_tax(63133)

# %% [markdown]
# # NumPy

# %%
import numpy as np

#from a list
array_from_list = np.array([1, 2, 3, 4])
print(array_from_list)

#using zeroes
zeros_array = np.zeros((2, 3))
print(zeros_array)
# Out:
# [1 2 3 4]
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
array = np.array([1, 2, 3, 4, 5])
print(array[0])
print(array[1:4])
print(array + 1)
print(array * 2)
# Out:
# 1
# [2 3 4]
# [2 3 4 5 6]
# [ 2  4  6  8 10]

# %%
matrix = np.array([[1, 2, 3], [4, 5, 6]])
print(matrix)

# %% [markdown]
# # Mathematical operations

# %%
matrix = np.array([1, 2], [3, 4])
determinant = np.linalg.det(matrix)
print(determinant)

# %%
import numpy as np

print(np.__version__)
# Out:
# 1.26.4

# %%
newList = [1, 2, 3]
np.array(newList)

# %%
np.arrange(0, 10)

# %%
np.arrange(0 , 11, 2)

# %%
np.random.rand(10)

# %%
np.random.rand(10)*10

# %%
np.random.rand(4, 4)

# %%
np.random.randint(1, 100, 10)

# %%
myIntArray = np.random.randint(1, 100, 10)
myIntArray

# %%
myIntArray.max()
myIntArray.argmax()
myIntArray.min()
myIntArray.argmin()
myIntArray[3]
myIntArray[2:5]

# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd

labels = ['a', 'b', 'c']
values = [7,8,9]
dictionary = {'a':7, 'b':8, 'c':9}

# %%
pd.Series(data=values, index=labels)

# %%
pd.Series(dictionary)

# %%
set1 = pd.Series(data=values, index=labels)
set2 = pd.Series(dictionary)
set3 = set1 + set2
set3

# %% [markdown]
# # Dataframe

# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}

df = pd.DataFrame(data)
print(df)

# %%
import pandas as pd

data = [
    ['Alice', 25, 'New York'],
    ['Bob', 30, 'Los Angeles'],
    ['Charlie', 35, 'Chicago']
]

columns = ['Name', 'Age', 'City']

df = pd.DataFrame(data, columns=columns)

print(df)

# %%
print(df.iloc[0])
print(df.loc[0])

# %% [markdown]
# # CSV files

# %%
df = pd.read_csv('data.csv')

print(df['Name'])

print(df[df['Age'] > 25])

df['Salary'] = [70000, 80000, 90000]
print(df)

grouped = df.groupby('City')
print(grouped['Age'].mean())

df.fillna(0, inplace=True)

df.dropna(inplace=True)

# %%
import numpy as np
import pandas as pd

labels_new = ['a', 'b', 'c']
values1= np.random.rand(20, 4)
values2= np.random.rand(20, 4)
values3= np.random.rand(20, 4)
cols = ['W', 'X', 'Y', 'Z']

multiArray = [values1.tolist(), values2.tolist(), values3.tolist()]

flattened_multiArr = [item for sublist in multiArray for item in sublist]

dataFrame = pd.DataFrame(data=flattened_multiArr, columns=cols)

dataFrame
# Out:
#            W         X         Y         Z
# 0   0.053658  0.891749  0.136886  0.676516
# 1   0.517299  0.730383  0.950864  0.833559
# 2   0.736789  0.144842  0.869749  0.368362
# 3   0.253387  0.960268  0.298020  0.731131
# 4   0.474302  0.995580  0.263277  0.260873
# 5   0.843857  0.241197  0.756605  0.845783
# 6   0.156269  0.260637  0.340815  0.907928
# 7   0.082069  0.062995  0.733348  0.920766
# 8   0.865808  0.278034  0.640922  0.905490
# 9   0.344353  0.884663  0.309399  0.990720
# 10  0.651813  0.704361  0.078532  0.574190
# 11  0.485596  0.360519  0.553330  0.578550
# 12  0.580343  0.865760  0.967075  0.894048
# 13  0.760117  0.265385  0.502313  0.774096
# 14  0.843083  0.635828  0.317488  0.042874
# 15  0.766730  0.263869  0.705161  0.242770
# 16  0.222220  0.229465  0.177108  0.941769
# 17  0.825229  0.470504  0.216519  0.914694
# 18  0.761745  0.356599  0.806759  0.743189
# 19  0.922617  0.477434  0.897377  0.511959
# 20  0.001975  0.502431  0.166829  0.125512
# ...

# %%
dataFrame.Z
# Out:
# 0     0.033871
# 1     0.234117
# 2     0.658057
# 3     0.102395
# 4     0.960586
# 5     0.557825
# 6     0.510174
# 7     0.387592
# 8     0.569505
# 9     0.901920
# 10    0.672201
# 11    0.161833
# 12    0.777435
# 13    0.897034
# 14    0.380705
# 15    0.356073
# 16    0.407064
# 17    0.967735
# 18    0.162435
# 19    0.134923
# 20    0.583264
# 21    0.740103
# 22    0.902113
# 23    0.789273
# 24    0.239025
# 25    0.951637
# 26    0.261502
# 27    0.705669
# 28    0.391412
# 29    0.462124
# 30    0.530460
# 31    0.144810
# 32    0.715732
# 33    0.978949
# 34    0.266243
# 35    0.785182
# 36    0.186610
# 37    0.174626
# 38    0.079321
# 39    0.285359
# 40    0.049903
# 41    0.942222
# 42    0.305998
# 43    0.679230
# 44    0.373074
# 45    0.882096
# 46    0.126105
# 47    0.242488
# 48    0.349705
# 49    0.172598
# 50    0.514872
# 51    0.368563
# 52    0.935794
# 53    0.565117
# 54    0.463958
# 55    0.928003
# 56    0.358545
# 57    0.087231
# ...

# %%
dataFrame['Sum(X+Y)'] = dataFrame['X'] + dataFrame['Y']
dataFrame
# Out:
#            W         X         Y         Z  Sum(X+Y)
# 0   0.053658  0.891749  0.136886  0.676516  1.028635
# 1   0.517299  0.730383  0.950864  0.833559  1.681248
# 2   0.736789  0.144842  0.869749  0.368362  1.014591
# 3   0.253387  0.960268  0.298020  0.731131  1.258288
# 4   0.474302  0.995580  0.263277  0.260873  1.258858
# 5   0.843857  0.241197  0.756605  0.845783  0.997802
# 6   0.156269  0.260637  0.340815  0.907928  0.601453
# 7   0.082069  0.062995  0.733348  0.920766  0.796342
# 8   0.865808  0.278034  0.640922  0.905490  0.918955
# 9   0.344353  0.884663  0.309399  0.990720  1.194062
# 10  0.651813  0.704361  0.078532  0.574190  0.782893
# 11  0.485596  0.360519  0.553330  0.578550  0.913849
# 12  0.580343  0.865760  0.967075  0.894048  1.832835
# 13  0.760117  0.265385  0.502313  0.774096  0.767698
# 14  0.843083  0.635828  0.317488  0.042874  0.953316
# 15  0.766730  0.263869  0.705161  0.242770  0.969030
# 16  0.222220  0.229465  0.177108  0.941769  0.406573
# ...

# %%
dataFrame.drop('Sum(X+Y)', axis=1, inplace=True)
dataFrame
# Out:
#            W         X         Y         Z
# 0   0.053658  0.891749  0.136886  0.676516
# 1   0.517299  0.730383  0.950864  0.833559
# 2   0.736789  0.144842  0.869749  0.368362
# 3   0.253387  0.960268  0.298020  0.731131
# 4   0.474302  0.995580  0.263277  0.260873
# 5   0.843857  0.241197  0.756605  0.845783
# 6   0.156269  0.260637  0.340815  0.907928
# 7   0.082069  0.062995  0.733348  0.920766
# 8   0.865808  0.278034  0.640922  0.905490
# 9   0.344353  0.884663  0.309399  0.990720
# 10  0.651813  0.704361  0.078532  0.574190
# 11  0.485596  0.360519  0.553330  0.578550
# 12  0.580343  0.865760  0.967075  0.894048
# 13  0.760117  0.265385  0.502313  0.774096
# 14  0.843083  0.635828  0.317488  0.042874
# 15  0.766730  0.263869  0.705161  0.242770
# 16  0.222220  0.229465  0.177108  0.941769
# 17  0.825229  0.470504  0.216519  0.914694
# 18  0.761745  0.356599  0.806759  0.743189
# 19  0.922617  0.477434  0.897377  0.511959
# 20  0.001975  0.502431  0.166829  0.125512
# ...

# %%
import numpy as np
import pandas as pd

titanicDf = pd.read_csv('Titanic-Dataset.csv')
titanicDf.head() #First 5 rows only
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanicDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanicDf.drop('Cabin', axis=1, inplace=True)
titanicDf.drop('Embarked', axis=1, inplace=True)
titanicDf.drop('PassengerID', axis=1, inplace=True)
titanicDf.info()

# %%
titanicDf[titanicDf['Age'].isnull()]

# %% [markdown]
# # Cleaning Data

# %%
indexAge = titanicDf[titanicDf['Age'].isnull()]
titanicDf.drop(indexAge, inplace=True)
titanicDf.info()

# %%
titanicDf.replace('male', 0, inplace=True)
titanicDf.replace('female', 1, inplace=True)
titanicDf.info()
